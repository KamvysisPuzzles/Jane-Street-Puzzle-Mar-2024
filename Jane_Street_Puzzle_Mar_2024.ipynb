# %% [markdown]
# Hi, This is my solution to Jane Street Puzzle for March 2024. You can find the puzzle in this link https://www.janestreet.com/puzzles/hooks-10-index/
# I managed to make the leaderboard.
#
# ![image.png](attachment:fa335b2f-f1dc-465e-af56-c07dea56dd9a.png)

# %% [markdown]
# ![image.png](attachment:408564a6-746f-4f62-a25b-bec067ace46f.png)

# %% [markdown]
# I would say the main hint would be to focus on number 31 on the Grid. 31 Limits the cells that can be adjecent to it so it gives valueable information as to what hooks need to go near it.

# %% [markdown]
# Here is my solution
#
# ![image.png](attachment:f11a115c-2b9a-42ef-897e-fe5e13601ffe.png)

# %% [markdown]
# After Finding a valid Grid Remove the aid numbers and calculate the product of unoccupied sections.

# %% [markdown]
# Here is the final answer

# %% [markdown]
# ![image.png](attachment:93f25e83-b753-475b-896f-87f0779d7eee.png)
